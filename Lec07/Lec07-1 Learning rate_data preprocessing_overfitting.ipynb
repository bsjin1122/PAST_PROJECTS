# %% [markdown]
# https://youtu.be/1jPjVoDV_uo
# ## lec 07-1: 학습 rate, Overfitting, 그리고 일반화 (Regularization)
# 데이터 선처리 방법, overfitting 을 방지하는 방법 등

# %% [markdown]
# ![image.png](attachment:136bc9f4-7678-471d-a1d9-d488285d400c.png)
# learning_rate이라는 알파값을 위처럼 나타낼 수 있다
# minimize할 때에는 learning_rate을 임의의값으로 나타내어 실습했다.

# %% [markdown]
# ![image.png](attachment:70263cd0-1fd1-4cb6-96cc-a52772edd94c.png)
# 경사면을 내려가는 한 스텝이 엄청 크면? 처음의 시작에서 보폭이 커져서 학습이 제대로 이루어지지 않게 된다.
# ![image.png](attachment:ee2332f8-485f-4ae1-be65-ad5cdaa76711.png) 이것을 overshooting이라고 한다.
# #### learning_rate을 정하는 기준은 환경에 따라 조금씩 다르기 때문에, 0.01부터 시작하면 된다.

# %% [markdown]
# ## X데이터를 선처리 해야 하는 경우
# ![image.png](attachment:8fd0036d-d7b6-4a76-8436-36848634a0c3.png)
#
# ![image.png](attachment:6f04de6e-8b18-4c81-9285-d28bae24bcb6.png)
# x값들간에 큰 차이가 발생하여 등고선을 그리게 된다면? 왜곡된 등고선 값이 나타날 것이다.
#
# ![image.png](attachment:a3d3106c-19c7-4454-a22d-75b1ddb4727d.png)
# alpha값이 작은 값임에도 불구하고, 튀어 나가는 형태가 되어 주의해야 한다.
# ![image.png](attachment:bc39320d-ea4c-43c0-bdae-eff729f4da67.png)
# normalize할 필요가 있다.
# 2차원 형태로 흩어져 있다고 보면, 가장 많이 쓰이는게 zero-centered data. <p></p>
# normalized data: 어떤 도면에 항상 들어가 있도록 함
# ### 데이터 중에 차이가 큰 게 있는지, normalized되었는지 확인 필요하다.

# %% [markdown]
# ![image.png](attachment:aa3df28d-680a-452e-aea6-15f978fae2cb.png)
#
# X의 값들이 있으면, x의 값을 계산한 평균과 분산을 가지고 계산한다.
# 아랫줄: 파이썬으로 쓰는 코드, Standardization 으로 처리해보면 좋다.

# %% [markdown]
# ## Overfitting
# 학습을 통해서 만들어가는데, 학습 데이터에 너무 잘 맞는 모델을 만들게 되면, 학습 데이터를 다시 가지고 물어보면 답을 하지만, 실제로 사용해보면 잘 안맞는 경우가 생긴다.
# ![image.png](attachment:bf4b86c3-a96b-4fe6-b82f-92257700323e.png)
# +, -를 구분한다고 가정, 대략 선으로 구분을 지으면 좋은 모델이다라고 말할 순 있겠지만,
# (model2) 일부러 꼬아서 한다면..
# ![image.png](attachment:96c65d10-7807-4001-b9b4-a651157b03b8.png)
#
# ## overfitting을 줄이려면?
# ### 트레이닝 데이터가 많으면 많을 수록 줄일 수 있다.
# ### feature의 중복된 개수를 줄여본다.

# %% [markdown]
# ## Regularization (일반화)
# weight을 너무나 큰 값을 가지지 말자.
# 구부린다. (weight은 어떤 경우엔 큰 값을 가질 경우)
#
#
# ![image.png](attachment:c003c92f-17cd-4031-8764-5716cba2586c.png)
# cost를 최소화시키는 것이 우리의 목표
# cost함수에 뒤에 각각의 엘리먼트를 제곱하고 더한 뒤에 regularization strength

# %% [markdown]
# ![image.png](attachment:96d1a6a1-4498-4f7d-a732-6c14d9aa7ebb.png)
