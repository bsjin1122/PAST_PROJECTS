# %% [markdown]
# https://youtu.be/E-io76NlsqA
# ## ML lab 06-2: TensorFlow로 Fancy Softmax Classification의 구현하기
# ### cross_entropy, one_hot, reshape

# %% [markdown]
# ![image.png](attachment:07f304c1-f51d-4578-9839-939a158d7551.png)
