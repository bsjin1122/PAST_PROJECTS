# %% [markdown]
# https://youtu.be/Y0EF9VqRuEA

# %%
# Lab 3 Minimizing Cost
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline

x_train = [1, 2, 3, 4]
y_train = [0, -1, -2, -3]

tf.model = tf.keras.Sequential()
tf.model.add(tf.keras.layers.Dense(units=1, input_dim=1))

sgd = tf.keras.optimizers.SGD(lr=0.1)
tf.model.compile(loss='mse', optimizer=sgd)

tf.model.summary()

# fit() trains the model and returns history of train
history = tf.model.fit(x_train, y_train, epochs=100)

y_predict = tf.model.predict(np.array([5, 4]))
print(y_predict)

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 2
#
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# C:\Users\user\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 1/1 [==============================] - 0s 396ms/step - loss: 1.5707
# Epoch 2/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.8101
# Epoch 3/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4624
# Epoch 4/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3005
# Epoch 5/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2223
# Epoch 6/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1821
# Epoch 7/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1592
# Epoch 8/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1443
# Epoch 9/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1333
# Epoch 10/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1244
# Epoch 11/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1165
# Epoch 12/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1094
# Epoch 13/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1029
# Epoch 14/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0968
# Epoch 15/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0910
# Epoch 16/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0857
# Epoch 17/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0806
# Epoch 18/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0758
# Epoch 19/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0714
# Epoch 20/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0672
# Epoch 21/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0632
# Epoch 22/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0595
# Epoch 23/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0560
# Epoch 24/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0527
# Epoch 25/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0496
# Epoch 26/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0466
# Epoch 27/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0439
# Epoch 28/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0413
# Epoch 29/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0389
# Epoch 30/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0366
# Epoch 31/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0344
# Epoch 32/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0324
# Epoch 33/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0305
# Epoch 34/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0287
# Epoch 35/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0270
# Epoch 36/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0254
# Epoch 37/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0239
# Epoch 38/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0225
# Epoch 39/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0212
# Epoch 40/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0199
# Epoch 41/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0187
# Epoch 42/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0176
# Epoch 43/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0166
# Epoch 44/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0156
# Epoch 45/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0147
# Epoch 46/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0138
# Epoch 47/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0130
# Epoch 48/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0122
# Epoch 49/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0115
# Epoch 50/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0108
# Epoch 51/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0102
# Epoch 52/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0096
# Epoch 53/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0090
# Epoch 54/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0085
# Epoch 55/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0080
# Epoch 56/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0075
# Epoch 57/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0071
# Epoch 58/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0067
# Epoch 59/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0063
# Epoch 60/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0059
# Epoch 61/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0056
# Epoch 62/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0052
# Epoch 63/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0049
# Epoch 64/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0046
# Epoch 65/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0044
# Epoch 66/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0041
# Epoch 67/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0039
# Epoch 68/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0036
# Epoch 69/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0034
# Epoch 70/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 71/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0030
# Epoch 72/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0028
# Epoch 73/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 74/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0025
# Epoch 75/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0024
# Epoch 76/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0022
# Epoch 77/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0021
# Epoch 78/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 79/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0019
# Epoch 80/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0017
# Epoch 81/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0016
# Epoch 82/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0015
# Epoch 83/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0015
# Epoch 84/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0014
# Epoch 85/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0013
# Epoch 86/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0012
# Epoch 87/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0011
# Epoch 88/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0011
# Epoch 89/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0010
# Epoch 90/100
# 1/1 [==============================] - 0s 1ms/step - loss: 9.5281e-04
# Epoch 91/100
# 1/1 [==============================] - 0s 11ms/step - loss: 8.9661e-04
# Epoch 92/100
# 1/1 [==============================] - 0s 4ms/step - loss: 8.4372e-04
# Epoch 93/100
# 1/1 [==============================] - 0s 15ms/step - loss: 7.9396e-04
# Epoch 94/100
# 1/1 [==============================] - 0s 5ms/step - loss: 7.4713e-04
# Epoch 95/100
# 1/1 [==============================] - 0s 15ms/step - loss: 7.0306e-04
# Epoch 96/100
# 1/1 [==============================] - 0s 5ms/step - loss: 6.6159e-04
# Epoch 97/100
# 1/1 [==============================] - 0s 0s/step - loss: 6.2257e-04
# Epoch 98/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.8585e-04
# Epoch 99/100
# 1/1 [==============================] - 0s 0s/step - loss: 5.5130e-04
# Epoch 100/100
# 1/1 [==============================] - 0s 1000us/step - loss: 5.1878e-04
# 1/1 [==============================] - 0s 116ms/step
# [[-3.9621217]
#  [-2.9805102]]

# %%
import tensorflow as tf

x_data = [1, 2, 3]
y_data = [1, 2, 3]

W = tf.Variable(tf.compat.v1.random_normal([1]), name='weight')
X = tf.compat.v1.placeholder(tf.float32)
Y = tf.compat.v1.placeholder(tf.float32)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 7
#       4 y_data = [1, 2, 3]
#       6 W = tf.Variable(tf.compat.v1.random_normal([1]), name='weight')
# ----> 7 X = tf.compat.v1.placeholder(tf.float32)
#       8 Y = tf.compat.v1.placeholder(tf.float32)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\ops\array_ops.py:3342, in placeholder(dtype, shape, name)
#    3295 """Inserts a placeholder for a tensor that will be always fed.
#    3296
#    3297 **Important**: This tensor will produce an error if evaluated. Its value must
#    (...)
#    3339 @end_compatibility
#    3340 """
#    3341 if context.executing_eagerly():
# -> 3342   raise RuntimeError("tf.placeholder() is not compatible with "
#    3343                      "eager execution.")
#    3345 return gen_array_ops.placeholder(dtype=dtype, shape=shape, name=name)
#
# RuntimeError: tf.placeholder() is not compatible with eager execution.

# %%
import tensorflow.compat.v1 as tf
tf.compat.v1.enable_eager_execution()
import matplotlib.pyplot as plt

X = [1, 2, 3]
Y = [1, 2, 3]

# 변수로 사용할 W 정의 (초기값은 0.0)
W = tf.Variable(0.0, dtype=tf.float32)

# Our hypothesis for linear model X * W
hypothesis = X * W

# cost/loss function 
def cost():
    return tf.reduce_mean(tf.square(hypothesis - Y))

# 경사 하강법 옵티마이저
optimizer = tf.compat.v1.train.GradientDescentOptimizer(learning_rate=0.01)

# 학습 루프
epochs = 100

for epoch in range(epochs):
    # 비용 함수를 최소화하기 위해 경사 하강법 수행
    optimizer.minimize(cost, var_list=[W])
    
    # 학습 결과 출력
    print(f"Epoch {epoch+1}: W={W.numpy()}, Cost={cost().numpy()}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 26
#      22 epochs = 100
#      24 for epoch in range(epochs):
#      25     # 비용 함수를 최소화하기 위해 경사 하강법 수행
# ---> 26     optimizer.minimize(cost, var_list=[W])
#      28     # 학습 결과 출력
#      29     print(f"Epoch {epoch+1}: W={W.numpy()}, Cost={cost().numpy()}")
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\training\optimizer.py:485, in Optimizer.minimize(self, loss, global_step, var_list, gate_gradients, aggregation_method, colocate_gradients_with_ops, name, grad_loss)
#     483 vars_with_grad = [v for g, v in grads_and_vars if g is not None]
#     484 if not vars_with_grad:
# --> 485   raise ValueError(
#     486       "No gradients provided for any variable, check your graph for ops"
#     487       " that do not support gradients, between variables %s and loss %s." %
#     488       ([str(v) for _, v in grads_and_vars], loss))
#     490 return self.apply_gradients(grads_and_vars, global_step=global_step,
#     491                             name=name)
#
# ValueError: No gradients provided for any variable, check your graph for ops that do not support gradients, between variables ["<tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.0>"] and loss <function cost at 0x0000028B05EB6440>.
