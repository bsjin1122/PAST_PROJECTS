# %% [markdown]
# ## Lec06-1_Softmax Regression 기본 개념 소개
# https://youtu.be/MFAnsx1y9ZI
#
# ![image.png](attachment:25365d49-677f-4d2f-894d-ff1349d09018.png)
# Y: real 데이터
# Y(hat): prediction
# ![image.png](attachment:4c9f251f-b9d4-4508-9de6-35e2a0e80162.png)
# ## Multinomial Classification 여러개의 클래스가 있다는 것
# ![image.png](attachment:c1d2a2df-331d-46cf-8cac-80d646ec7469.png)
# 3개의 각각의 다른 Binary classification으로도 구현이 가능하다.
# ![image.png](attachment:e47ef599-2f05-4842-8a14-8ebc7246aaee.png)

# %% [markdown]
# ![image.png](attachment:8de3cec9-be60-4dc4-a043-5b855fd6c3bc.png)
# 해당 W(a, b, c)의 hypothesis값으로 나타낼 수 있다.

# %% [markdown]
# ![image.png](attachment:dafd3424-f92b-49c4-b8cb-02b42d288514.png)
# 0.7 + 0.2 + 0.1 = 1.0
# SoftMax 함수란?
# n개의 값을 softmax에 넣게 되면, 0.7, 0.2, 0.1처럼 만들어준다. 확률로 볼 수 있다.
# 1) 0~1 사이의 값이다.
# 2) 전체 sum = 1
# - 제일 큰 값은 1.0, 나머지는 0.0 -> ONE-HOT ENCODING

# %% [markdown]
# ![image.png](attachment:a707052e-af9c-4704-8eb6-26b3231aec13.png)

# %% [markdown]
# ![image.png](attachment:15fd487d-d3bc-47bc-bf1b-93e17abd492d.png)
#
#
# cost가 0이되게 하는 것이 좋은 것. 두 개의 합을 하게 되면, 0(무한대) 굉장히 큰 값이 나옴
