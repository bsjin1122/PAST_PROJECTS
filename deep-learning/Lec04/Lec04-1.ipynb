# %% [markdown]
# ## ML lec 04 - multi-variable linear regression
#
# linear regression에서 필요한 세가지 : Hypothesis, Cost function, Gradient descent algorithm
# ![image.png](attachment:a0e6bff6-accf-4755-b20f-3817a781c51b.png)
#
# ![image.png](attachment:a2fcbd9a-f868-4118-a93f-99045730bceb.png)
#
# ![image.png](attachment:aad27020-d15b-4822-a60a-34fcad4f205f.png)

# %% [markdown]
# ---
#
# ![image.png](attachment:b48ddd7e-2c83-40c5-97af-c8a4ef709eb3.png)
#
# w와 x의 값이 바뀐듯 해보이지만, 매트릭스를 쓸 때 보통은 X를 앞에 쓴다.
# 대문자는 또 매트릭스라는 뜻이기도 하다.
#
# wx라고 쓰지만, 매트릭스는 xw를 사용한다.  (식은 동일함)

# %% [markdown]
# ![image.png](attachment:11a42165-945b-4de6-8c3c-6430c1634999.png)
# 각각의 인스턴스를 서로 매번 곱해줄 필요없이, 전체를 긴 매트릭스에 넣고,
# 인스턴스의 수만큼 넣고 w매트릭스를 곱하면 한번에 확인할 수 있다.

# %% [markdown]
# ![image.png](attachment:8ef880f8-9ebf-46d0-8222-93afd13c4c92.png)
#
# 5(인스턴스의 개수): 늘어날수록 가변하는 값이다.
#
# 3: x의 variable의 개수
#
# 3과 3이 같아야 한다.
# Weight의 크기를 결정하려면? (3,1)
#
# ![image.png](attachment:a9a7702f-6b4f-4403-8c7e-0f1c9bf66f7b.png)
# * 참고로 b bias 코드는 생략한다.
