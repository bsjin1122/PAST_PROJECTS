# %% [markdown]
# ## ML lec 5-1: Logistic Classification의 가설 함수 정의
#
# ![image.png](attachment:3d5f65b0-bf93-4f04-98c0-3940ff4bf2c4.png)
#
# cost를 최소화하는 Weight를 찾아내는 것. 밥그릇과 같은 모양. <p></p>
# `경사 타고 내려가기` 알고리즘을 사용. 어떤 점에서 시작하더라도, <p></p>
#
# 경사가 어디로 향해 있는지 `기울기`를 본 다음, `한 발자국 움직임.` <p></p>
# 끝까지 알고리즘을 쓰게 되면 어느 시점에서 최대점을 찾게 됨
#
# 기울기란 cost 함수를 미분한 값으로 나타남. 한 번에 얼마나 움직일까.는 a(알파, `learning_rate`라고도 불림, step의 size)
# ![image.png](attachment:a3096e0c-0b00-4ddc-bfc2-3aa642d9258d.png)
#
# classification의 다른 점은 이전에는 숫자를 그저 예측하는 것이었다면, <p></p>
# Binary Classification 은 둘 중 하나를 정해진 카테고리를 고르는 것. <p></p>
# ex)
# - `스팸 이메일`인지를 판단.
# - Facebook 타임라인 재밌는 것만
#     - 굉장히 좋은 것, 재밌는 것만 올라오면서 더 많은 시간을 보내게 한다.
# - Credit card 기존 사용하던 결제 패턴에서 분석.

# %% [markdown]
# ![image.png](attachment:cc56feaa-5b56-43b4-b1f1-b20947075817.png)
#
# ![image.png](attachment:e2794b4a-ca44-43cb-a3ec-6a1c9f472151.png)
#
# ## sigmoid
# ## Logistic Function
# ![image.png](attachment:dbe3e5f7-aa70-47d1-9e67-b146e5e450a1.png)
# x축: z
# y축: g(z)
# x축이 커지면, y의 값은 1에 가까워진다. 더 커지지 않는다.

# %% [markdown]
# ## Z = WX
# ## H(x) = g(z)
#
# ![image.png](attachment:06e086ce-d025-4ed8-aaac-5a41ecf94a86.png) `sigmoid`
