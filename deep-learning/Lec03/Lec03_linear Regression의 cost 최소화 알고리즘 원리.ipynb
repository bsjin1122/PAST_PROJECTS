# %% [markdown]
# https://youtu.be/TxIVr-nk1so

# %% [markdown]
# ![image.png](attachment:9fd3c9c6-b8b9-4e73-b968-9efd6f178b42.png)
# cost 라는 함수를 들여다보자.
# (1*1-1)^2 + (1*2-2)+(1*3-3)
#
# cost가 0인 곳을 찾아내는 것이다.

# %% [markdown]
# ![image.png](attachment:1c7a5ba3-b8e1-4864-8a7c-91cec5fc8a8a.png)

# %% [markdown]
# ## Gradient descent algorithm
# 경사에 따라 내려가는 알고리즘<br>
# cost function을 minimize하는데 많이 사용됨<br>
#
# 아무데서나 시작 가능, W 값 변경 가능. cost를 줄이게 됨.<br>
# 경사도를 계속해서 과정을 반복한다.<br>
# ### 미분: 경사도를 구하는 것

# %% [markdown]
# ![image.png](attachment:790253da-950c-46a7-b6f3-006cee1fdedd.png)

# %% [markdown]
# ## 미분하는 방법
#
# ![image.png](attachment:ed86fb92-646d-4d52-8aa0-49d8f1a1e9b7.png)

# %% [markdown]
# 반드시 cost function을 사용할 때, convex function의 모양을 확인한다.
# 어느 점에서 시작하든 간에, 도착지점이 원하는 지점을 보장하게 해준다.
#
# ![image.png](attachment:308f0537-2ebb-45f0-9c3f-caad5b76f91f.png)
